# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import plot_roc_curve, roc_auc_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
pd.set_option('display.float_format', lambda x: '%.5f' % x)
import os

# %%
data_filename = 'hotel_bookings.csv'
data_path = os.path.join(os.path.abspath('../Project_Python/Data'), data_filename)


folder_path = os.path.abspath('../Project_Python/Data')


data_df = pd.read_csv(data_path)

# %%
# data_df = pd.read_csv('hotel_bookings.csv')

# data_df = data_df.drop(columns=['reservation_status_date'])

# %%
nan_replacements = {"children:": 0.0,"country": "Unknown", "agent": 0, "company": 0}
data_df_clean = data_df.fillna(nan_replacements)
data_df_clean["meal"].replace("Undefined", "SC", inplace=True)

# Some rows contain entreis with 0 adults, 0 children and 0 babies. 
# I'm dropping these entries with no guests.
zero_guests = list(data_df_clean.loc[data_df_clean["adults"]
                   + data_df_clean["children"]
                   + data_df_clean["babies"]==0].index)
data_df_clean.drop(data_df_clean.index[zero_guests], inplace=True)

# %%
# my_label_encoder = LabelEncoder()

# for el in data_df:
#     if data_df[el].dtype == object:
#         my_label_encoder.fit(data_df[el]) 
#         tmp = my_label_encoder.transform(data_df[el]).reshape((-1,1))
#         data_df[el] = pd.DataFrame(tmp)

# %% [markdown]
# Piotr - Random Forest Estimation

# %%
data_df.describe()
# Out:
#        is_canceled    lead_time  arrival_date_year  arrival_date_week_number  \
# count 119390.00000 119390.00000       119390.00000              119390.00000
# mean       0.37042    104.01142         2016.15655                  27.16517
# std        0.48292    106.86310            0.70748                  13.60514
# min        0.00000      0.00000         2015.00000                   1.00000
# 25%        0.00000     18.00000         2016.00000                  16.00000
# 50%        0.00000     69.00000         2016.00000                  28.00000
# 75%        1.00000    160.00000         2017.00000                  38.00000
# max        1.00000    737.00000         2017.00000                  53.00000
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count               119390.00000             119390.00000
# mean                    15.79824                  0.92760
# std                      8.78083                  0.99861
# min                      1.00000                  0.00000
# 25%                      8.00000                  0.00000
# 50%                     16.00000                  1.00000
# 75%                     23.00000                  2.00000
# max                     31.00000                 19.00000
#
#        stays_in_week_nights       adults     children       babies  \
# count          119390.00000 119390.00000 119386.00000 119390.00000
# mean                2.50030      1.85640      0.10389      0.00795
# std                 1.90829      0.57926      0.39856      0.09744
# min                 0.00000      0.00000      0.00000      0.00000
# 25%                 1.00000      2.00000      0.00000      0.00000
# 50%                 2.00000      2.00000      0.00000      0.00000
# 75%                 3.00000      2.00000      0.00000      0.00000
# max                50.00000     55.00000     10.00000     10.00000
#
#        is_repeated_guest  previous_cancellations  \
# count       119390.00000            119390.00000
# mean             0.03191                 0.08712
# std              0.17577                 0.84434
# min              0.00000                 0.00000
# 25%              0.00000                 0.00000
# 50%              0.00000                 0.00000
# 75%              0.00000                 0.00000
# max              1.00000                26.00000
#
#        previous_bookings_not_canceled  booking_changes        agent  \
# count                    119390.00000     119390.00000 103050.00000
# mean                          0.13710          0.22112     86.69338
# std                           1.49744          0.65231    110.77455
# min                           0.00000          0.00000      1.00000
# 25%                           0.00000          0.00000      9.00000
# 50%                           0.00000          0.00000     14.00000
# 75%                           0.00000          0.00000    229.00000
# max                          72.00000         21.00000    535.00000
#
#          company  days_in_waiting_list          adr  \
# count 6797.00000          119390.00000 119390.00000
# mean   189.26674               2.32115    101.83112
# std    131.65501              17.59472     50.53579
# min      6.00000               0.00000     -6.38000
# 25%     62.00000               0.00000     69.29000
# 50%    179.00000               0.00000     94.57500
# 75%    270.00000               0.00000    126.00000
# max    543.00000             391.00000   5400.00000
#
#        required_car_parking_spaces  total_of_special_requests
# count                 119390.00000               119390.00000
# mean                       0.06252                    0.57136
# std                        0.24529                    0.79280
# min                        0.00000                    0.00000
# 25%                        0.00000                    0.00000
# 50%                        0.00000                    0.00000
# 75%                        0.00000                    1.00000
# max                        8.00000                    5.00000

# %%
#sns.distplot(data_df['is_canceled'])
data_df.corr(method='spearman')
# Out:
#                                 is_canceled  lead_time  arrival_date_year  \
# is_canceled                         1.00000    0.31663            0.01807
# lead_time                           0.31663    1.00000            0.05665
# arrival_date_year                   0.01807    0.05665            1.00000
# arrival_date_week_number            0.00759    0.11251           -0.54482
# arrival_date_day_of_month          -0.00614    0.00754           -0.00118
# stays_in_weekend_nights            -0.00411    0.16211            0.02480
# stays_in_week_nights                0.04142    0.29634            0.04130
# adults                              0.06703    0.19224            0.04287
# children                           -0.00279   -0.01616            0.05788
# babies                             -0.03431   -0.01978           -0.01327
# is_repeated_guest                  -0.08479   -0.19019            0.01038
# previous_cancellations              0.27023    0.17080           -0.25768
# previous_bookings_not_canceled     -0.11535   -0.18861            0.03627
# booking_changes                    -0.18511   -0.00777            0.02256
# agent                              -0.11497   -0.12338            0.10720
# company                            -0.01134    0.28599            0.23435
# days_in_waiting_list                0.09824    0.15321           -0.08306
# adr                                 0.05088    0.01503            0.21956
# required_car_parking_spaces        -0.19740   -0.14155           -0.01630
# total_of_special_requests          -0.25852   -0.07411            0.11560
#
#                                 arrival_date_week_number  \
# is_canceled                                      0.00759
# lead_time                                        0.11251
# arrival_date_year                               -0.54482
# arrival_date_week_number                         1.00000
# arrival_date_day_of_month                        0.06075
# stays_in_weekend_nights                          0.02560
# stays_in_week_nights                             0.02590
# adults                                           0.02632
# children                                         0.00642
# babies                                           0.01254
# is_repeated_guest                               -0.03038
# previous_cancellations                           0.08692
# previous_bookings_not_canceled                  -0.04314
# booking_changes                                  0.00786
# agent                                           -0.05707
# company                                         -0.05797
# days_in_waiting_list                            -0.00353
# adr                                              0.07362
# required_car_parking_spaces                      0.00314
# total_of_special_requests                        0.01905
#
#                                 arrival_date_day_of_month  \
# is_canceled                                      -0.00614
# lead_time                                         0.00754
# arrival_date_year                                -0.00118
# arrival_date_week_number                          0.06075
# arrival_date_day_of_month                         1.00000
# stays_in_weekend_nights                          -0.00672
# stays_in_week_nights                             -0.01551
# adults                                            0.00152
# children                                          0.01565
# babies                                            0.00046
# is_repeated_guest                                -0.00608
# previous_cancellations                           -0.01194
# previous_bookings_not_canceled                   -0.00138
# booking_changes                                   0.01246
# agent                                             0.00476
# company                                           0.04551
# days_in_waiting_list                              0.03221
# adr                                               0.02675
# required_car_parking_spaces                       0.00851
# total_of_special_requests                         0.00309
#
#                                 stays_in_weekend_nights  stays_in_week_nights  \
# is_canceled                                    -0.00411               0.04142
# lead_time                                       0.16211               0.29634
# arrival_date_year                               0.02480               0.04130
# arrival_date_week_number                        0.02560               0.02590
# arrival_date_day_of_month                      -0.00672              -0.01551
# stays_in_weekend_nights                         1.00000               0.23805
# stays_in_week_nights                            0.23805               1.00000
# adults                                          0.12675               0.15296
# children                                        0.05284               0.05430
# babies                                          0.02270               0.02646
# is_repeated_guest                              -0.09707              -0.12840
# previous_cancellations                         -0.05498              -0.06217
# previous_bookings_not_canceled                 -0.08360              -0.11910
# booking_changes                                 0.04037               0.06448
# agent                                           0.13140               0.17042
# company                                         0.07619               0.24987
# days_in_waiting_list                           -0.07475               0.01174
# adr                                             0.05137               0.09380
# required_car_parking_spaces                    -0.01862              -0.03385
# total_of_special_requests                       0.07938               0.07623
#
#                                  adults  children   babies  is_repeated_guest  \
# is_canceled                     0.06703  -0.00279 -0.03431           -0.08479
# lead_time                       0.19224  -0.01616 -0.01978           -0.19019
# arrival_date_year               0.04287   0.05788 -0.01327            0.01038
# arrival_date_week_number        0.02632   0.00642  0.01254           -0.03038
# arrival_date_day_of_month       0.00152   0.01565  0.00046           -0.00608
# stays_in_weekend_nights         0.12675   0.05284  0.02270           -0.09707
# stays_in_week_nights            0.15296   0.05430  0.02646           -0.12840
# adults                          1.00000   0.07210  0.02767           -0.17697
# children                        0.07210   1.00000  0.03927           -0.03473
# babies                          0.02767   0.03927  1.00000           -0.00942
# is_repeated_guest              -0.17697  -0.03473 -0.00942            1.00000
# previous_cancellations         -0.03599  -0.05864 -0.01729            0.15332
# previous_bookings_not_canceled -0.20962  -0.03520 -0.01111            0.75707
# booking_changes                -0.08499   0.06589  0.11606            0.01834
# agent                          -0.05595   0.03921  0.04320            0.02828
# company                         0.23041   0.02780  0.01936           -0.28422
# days_in_waiting_list           -0.03653  -0.04808 -0.01411           -0.02759
# adr                             0.27977   0.26546  0.02609           -0.15139
# required_car_parking_spaces     0.01791   0.06098  0.04058            0.07532
# total_of_special_requests       0.16156   0.09566  0.09283            0.00553
#
#                                 previous_cancellations  \
# is_canceled                                    0.27023
# lead_time                                      0.17080
# arrival_date_year                             -0.25768
# arrival_date_week_number                       0.08692
# arrival_date_day_of_month                     -0.01194
# stays_in_weekend_nights                       -0.05498
# stays_in_week_nights                          -0.06217
# adults                                        -0.03599
# children                                      -0.05864
# babies                                        -0.01729
# is_repeated_guest                              0.15332
# previous_cancellations                         1.00000
# previous_bookings_not_canceled                 0.10167
# booking_changes                               -0.07266
# agent                                         -0.16817
# company                                       -0.19818
# days_in_waiting_list                           0.11630
# adr                                           -0.14984
# required_car_parking_spaces                   -0.04388
# total_of_special_requests                     -0.12945
#
#                                 previous_bookings_not_canceled  \
# is_canceled                                           -0.11535
# lead_time                                             -0.18861
# arrival_date_year                                      0.03627
# arrival_date_week_number                              -0.04314
# arrival_date_day_of_month                             -0.00138
# stays_in_weekend_nights                               -0.08360
# stays_in_week_nights                                  -0.11910
# adults                                                -0.20962
# children                                              -0.03520
# babies                                                -0.01111
# is_repeated_guest                                      0.75707
# previous_cancellations                                 0.10167
# previous_bookings_not_canceled                         1.00000
# booking_changes                                        0.03068
# agent                                                  0.05992
# company                                               -0.29766
# days_in_waiting_list                                  -0.01887
# adr                                                   -0.14278
# required_car_parking_spaces                            0.10391
# total_of_special_requests                              0.02502
#
#                                 booking_changes    agent  company  \
# is_canceled                            -0.18511 -0.11497 -0.01134
# lead_time                              -0.00777 -0.12338  0.28599
# arrival_date_year                       0.02256  0.10720  0.23435
# arrival_date_week_number                0.00786 -0.05707 -0.05797
# arrival_date_day_of_month               0.01246  0.00476  0.04551
# stays_in_weekend_nights                 0.04037  0.13140  0.07619
# stays_in_week_nights                    0.06448  0.17042  0.24987
# adults                                 -0.08499 -0.05595  0.23041
# children                                0.06589  0.03921  0.02780
# babies                                  0.11606  0.04320  0.01936
# is_repeated_guest                       0.01834  0.02828 -0.28422
# previous_cancellations                 -0.07266 -0.16817 -0.19818
# previous_bookings_not_canceled          0.03068  0.05992 -0.29766
# booking_changes                         1.00000  0.09099  0.17612
# agent                                   0.09099  1.00000  0.22569
# company                                 0.17612  0.22569  1.00000
# days_in_waiting_list                   -0.01896 -0.01872  0.02108
# adr                                     0.00523 -0.04897  0.05228
# required_car_parking_spaces             0.07566  0.16480 -0.02382
# total_of_special_requests               0.04191  0.01545 -0.12776
#
#                                 days_in_waiting_list      adr  \
# is_canceled                                  0.09824  0.05088
# lead_time                                    0.15321  0.01503
# arrival_date_year                           -0.08306  0.21956
# arrival_date_week_number                    -0.00353  0.07362
# arrival_date_day_of_month                    0.03221  0.02675
# stays_in_weekend_nights                     -0.07475  0.05137
# stays_in_week_nights                         0.01174  0.09380
# adults                                      -0.03653  0.27977
# children                                    -0.04808  0.26546
# babies                                      -0.01411  0.02609
# is_repeated_guest                           -0.02759 -0.15139
# previous_cancellations                       0.11630 -0.14984
# previous_bookings_not_canceled              -0.01887 -0.14278
# booking_changes                             -0.01896  0.00523
# agent                                       -0.01872 -0.04897
# company                                      0.02108  0.05228
# days_in_waiting_list                         1.00000 -0.03952
# adr                                         -0.03952  1.00000
# required_car_parking_spaces                 -0.04340  0.03271
# total_of_special_requests                   -0.12328  0.19640
#
#                                 required_car_parking_spaces  \
# is_canceled                                        -0.19740
# lead_time                                          -0.14155
# arrival_date_year                                  -0.01630
# arrival_date_week_number                            0.00314
# arrival_date_day_of_month                           0.00851
# stays_in_weekend_nights                            -0.01862
# stays_in_week_nights                               -0.03385
# adults                                              0.01791
# children                                            0.06098
# babies                                              0.04058
# is_repeated_guest                                   0.07532
# previous_cancellations                             -0.04388
# previous_bookings_not_canceled                      0.10391
# booking_changes                                     0.07566
# agent                                               0.16480
# company                                            -0.02382
# days_in_waiting_list                               -0.04340
# adr                                                 0.03271
# required_car_parking_spaces                         1.00000
# total_of_special_requests                           0.08760
#
#                                 total_of_special_requests
# is_canceled                                      -0.25852
# lead_time                                        -0.07411
# arrival_date_year                                 0.11560
# arrival_date_week_number                          0.01905
# arrival_date_day_of_month                         0.00309
# stays_in_weekend_nights                           0.07938
# stays_in_week_nights                              0.07623
# adults                                            0.16156
# children                                          0.09566
# babies                                            0.09283
# is_repeated_guest                                 0.00553
# previous_cancellations                           -0.12945
# previous_bookings_not_canceled                    0.02502
# booking_changes                                   0.04191
# agent                                             0.01545
# company                                          -0.12776
# days_in_waiting_list                             -0.12328
# adr                                               0.19640
# required_car_parking_spaces                       0.08760
# total_of_special_requests                         1.00000

# %%
# # One-hot encode the data using pandas get_dummies
# data_df = pd.get_dummies(data_df)
# # Display the first 5 rows of the last 12 columns
# data_df.head()

# %%
# # Labels are the values we want to predict
# labels = np.array(data_df['is_canceled'])

# # Remove the labels from the features
# # axis 1 refers to the columns
# data_df= data_df.drop('is_canceled', axis = 1)

# # Saving feature names for later use
# feature_list = list(data_df.columns)
# # Convert to numpy array
# features = np.array(data_df)

# %%
# manually choose columns to include
# some columns are excluded to make the model more general and to prevent leakage
# (arrival_date_year, assigned_room_type, booking_changes, reservation_status, country,
# days_in_waiting_list)
# including the country would increase accuracy, but it may also make the model less general


# common:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px
import folium

# for ML:
from sklearn.model_selection import train_test_split, KFold, cross_validate, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import eli5 # Feature importance evaluation


full_data = data_df
num_features = ["lead_time","arrival_date_week_number","arrival_date_day_of_month",
                "stays_in_weekend_nights","stays_in_week_nights","adults","children",
                "babies","is_repeated_guest", "previous_cancellations",
                "previous_bookings_not_canceled","agent","company",
                "required_car_parking_spaces", "total_of_special_requests", "adr"]

cat_features = ["hotel","arrival_date_month","meal","market_segment",
                "distribution_channel","reserved_room_type","deposit_type","customer_type"]

# Separate features and predicted value
features = num_features + cat_features
X = full_data.drop(["is_canceled"], axis=1)[features]
y = full_data["is_canceled"]

# preprocess numerical feats:
# for most num cols, except the dates, 0 is the most logical choice as fill value
# and here no dates are missing.
num_transformer = SimpleImputer(strategy="constant")

# Preprocessing for categorical features:
cat_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="constant", fill_value="Unknown")),
    ("onehot", OneHotEncoder(handle_unknown='ignore'))])

# Bundle preprocessing for numerical and categorical features:
preprocessor = ColumnTransformer(transformers=[("num", num_transformer, num_features),
                                               ("cat", cat_transformer, cat_features)])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
# define models to test:
base_models = [("DT_model", DecisionTreeClassifier(random_state=42)),
               ("RF_model", RandomForestClassifier(random_state=42,n_jobs=-1)),
               ("LR_model", LogisticRegression(random_state=42,n_jobs=-1)),
               ("XGB_model", XGBClassifier(random_state=42, n_jobs=-1))]

# split data into 'kfolds' parts for cross validation,
# use shuffle to ensure random distribution of data:
kfolds = 4 # 4 = 75% train, 25% validation
split = KFold(n_splits=kfolds, shuffle=True, random_state=42)

# Preprocessing, fitting, making predictions and scoring for every model:
for name, model in base_models:
    # pack preprocessing of data and the model in a pipeline:
    model_steps = Pipeline(steps=[('preprocessor', preprocessor),
                              ('model', model)])
    
    # get cross validation score for each model:
    cv_results = cross_val_score(model_steps, 
                                 X, y, 
                                 cv=split,
                                 scoring="accuracy",
                                 n_jobs=-1)
    # output:
    min_score = round(min(cv_results), 4)
    max_score = round(max(cv_results), 4)
    mean_score = round(np.mean(cv_results), 4)
    std_dev = round(np.std(cv_results), 4)
    print(f"{name} cross validation accuracy score: {mean_score} +/- {std_dev} (std) min: {min_score}, max: {max_score}")
    
    #pipeline.fit(X_train, y_train)
    #preds = pipeline.predict(X_valid)
    #score = accuracy_score(y_valid, preds)
    #print(f"{name} accuracy_score: {round(score, 4)}")

# %%
rf_model_enh = RandomForestClassifier(n_estimators=160,
                               max_features=0.4,
                               min_samples_split=2,
                               n_jobs=-1,
                               random_state=0)

split = KFold(n_splits=kfolds, shuffle=True, random_state=42)
model_pipe = Pipeline(steps=[('preprocessor', preprocessor),
                              ('model', rf_model_enh)])
cv_results = cross_val_score(model_pipe, 
                                 X, y, 
                                 cv=split,
                                 scoring="accuracy",
                                 n_jobs=-1)
# output:
min_score = round(min(cv_results), 4)
max_score = round(max(cv_results), 4)
mean_score = round(np.mean(cv_results), 4)
std_dev = round(np.std(cv_results), 4)
print(f"Enhanced RF model cross validation accuracy score: {mean_score} +/- {std_dev} (std) min: {min_score}, max: {max_score}")

# %%
# fit model(pipeline) so values can be accessed:
model_pipe.fit(X,y)

# Names of all (encoded) features are needed.
# Get names of columns from One Hot Encoding:
onehot_columns = list(model_pipe.named_steps['preprocessor'].
                      named_transformers_['cat'].
                      named_steps['onehot'].
                      get_feature_names(input_features=cat_features))

# Add num_features for full list.
# Order must be as in definition of X, where num_features are first: 
feat_imp_list = num_features + onehot_columns

# show 10 most important features, provide names of features:
feat_imp_df = eli5.formatters.as_dataframe.explain_weights_df(
    model_pipe.named_steps['model'],
    feature_names=feat_imp_list)
feat_imp_df.head(10)
