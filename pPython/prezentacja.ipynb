# %%
from IPython.display import Image
Image("wykres_1.png", width=700)

# %%
Image("wykres_2.png", width=700)

# %%
Image("wykres_3.png", width=300)

# %%
Image("wykres_4.png")

# %%
Image("wykres_5.png", width=700)

# %%
Image("wykres_6.png", width=700)

# %%
Image("wykres_7.png", width=700)
